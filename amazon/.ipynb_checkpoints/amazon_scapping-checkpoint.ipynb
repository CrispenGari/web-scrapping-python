# %%
import requests, json, re
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = "https://twitter.com/home"
amazon = "https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_2?ie=UTF8&pg=2"
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
req = requests.get(amazon, headers=headers)

# %%
soup = bs(req.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
product = soup.find('div', {"class": "a-section a-spacing-none aok-relative"})
product
# Out:
# <div class="a-section a-spacing-none aok-relative"><div class="a-row a-spacing-none aok-inline-block"><span class="a-size-small aok-float-left zg-badge-body zg-badge-color"><span class="zg-badge-text">#51</span></span><span class="aok-float-left zg-badge-triangle zg-badge-color"></span></div><span class="aok-inline-block zg-item"><a class="a-link-normal" href="/NCERT-Textbooks-English-class-12/dp/B08K4JM83V/ref=zg_bs_books_51/259-0858762-6279266?_encoding=UTF8&amp;psc=1&amp;refRID=RE5PT2HFCGREYJA5M05D"><span class="zg-text-center-align"><div class="a-section a-spacing-small"><img alt="NCERT Textbooks in English for class 12 - Flamingo and Vistas - 12074 &amp;12075" height="200" src="https://images-eu.ssl-images-amazon.com/images/I/61QyHl9wiDL._AC_UL200_SR200,200_.jpg" width="200"/></div></span>
# <div aria-hidden="true" class="p13n-sc-truncate p13n-sc-line-clamp-1 p13n-sc-truncate-desktop-type2" data-rows="1">
# ...

# %%
product_number = int(str(product.div.span.span.string)[1:])
product_number
# Out:
# 51

# %%
image = product.find('img')
image_url = image["src"]
product_name = image['alt']
print(image_url, product_name)
# Out:
# https://images-eu.ssl-images-amazon.com/images/I/61QyHl9wiDL._AC_UL200_SR200,200_.jpg NCERT Textbooks in English for class 12 - Flamingo and Vistas - 12074 &12075

# %%
product_ratting_price = product.find('div', {"class":"a-icon-row"})

product_price = float(re.findall(r'\d+.\d{2}', product.find('span', {'class': 'p13n-sc-price'}).string)[0])

ratting_ratting = product_ratting_price.find('a').i.span.string

product_ratting = float(re.findall('\d{1}.\d{1}', ratting_ratting)[0])
print(product_ratting, product_price)
# Out:
# 4.5 94.0

# %%
product_seller = product.find('a', {'class': 'a-size-small a-link-child'}).string
product_seller
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-59989d0978de> in <module>
# ----> 1 product_seller = product.find('a', {'class': 'a-size-small a-link-child'}).string
#       2 product_seller
#
# AttributeError: 'NoneType' object has no attribute 'string'

# %%
### Now we can  loop throgh all the products and find what we want

# %%
products = soup.findAll('div', {"class": "a-section a-spacing-none aok-relative"})
len(products)
# Out:
# 50

# %%
products[3]
# Out:
# <div class="a-section a-spacing-none aok-relative"><div class="a-row a-spacing-none aok-inline-block"><span class="a-size-small aok-float-left zg-badge-body zg-badge-color"><span class="zg-badge-text">#54</span></span><span class="aok-float-left zg-badge-triangle zg-badge-color"></span></div><span class="aok-inline-block zg-item"><a class="a-link-normal" href="/Think-Grow-Rich-Napoleon-Hill/dp/8192910911/ref=zg_bs_books_54/259-0858762-6279266?_encoding=UTF8&amp;psc=1&amp;refRID=RE5PT2HFCGREYJA5M05D"><span class="zg-text-center-align"><div class="a-section a-spacing-small"><img alt="Think and Grow Rich" height="200" src="https://images-eu.ssl-images-amazon.com/images/I/71AdHA%2BqqwL._AC_UL200_SR200,200_.jpg" width="200"/></div></span>
# <div aria-hidden="true" class="p13n-sc-truncate p13n-sc-line-clamp-1 p13n-sc-truncate-desktop-type2" data-rows="1">
#             Think and Grow Rich
#         </div>
# ...

# %%
books = []
for product in products[:50]:
    # product number
    product_number = int(str(product.div.span.span.string)[1:])
    # product name and image
    image = product.find('img')
    image_url = image["src"]
    product_name = image['alt']
    # product ratting and price
    product_ratting_price = product.find('div', {"class":"a-icon-row"})
    product_price = float(re.findall(r'\d+.\d{2}', str(product.find('span', {'class': 'p13n-sc-price'}).string).replace(',', ''))[0])
    
    try:
        ratting_ratting = product_ratting_price.find('a').i.span.string
        product_ratting = float(re.findall('\d{1}.\d{1}', ratting_ratting)[0])
    except:
        product_ratting = 2.5
    # prodcuct seller
    
    try:
        product_seller = str(product.find('a', {'class': 'a-size-small a-link-child'}).text)
    except Exception as e:
        product_seller = "Unknown"
    
    product_seller
    book = {
        "description": product_name,
        "image": image_url,
        "number":product_number,
        "seller":product_seller,
        "price": product_price,
        "ratting": product_ratting 
    }
    books.append(book)

# %%
books[:1]
# Out:
# [{'description': 'NCERT Textbooks in English for class 12 - Flamingo and Vistas - 12074 &12075',
#   'image': 'https://images-eu.ssl-images-amazon.com/images/I/61QyHl9wiDL._AC_UL200_SR200,200_.jpg',
#   'number': 51,
#   'seller': 'Unknown',
#   'price': 94.0,
#   'ratting': 4.5}]

# %% [markdown]
# ## Now we can save our data to files

# %% [markdown]
# #### 1. json file

# %%
file = open('files/amazon_books.json', 'w')
file.write(json.dumps(books))
file.close()
print("THE FILE HAS BEEN SAVED")
# Out:
# THE FILE HAS BEEN SAVED

# %% [markdown]
# #### 2. csv file

# %%
import csv
keys = books[0].keys()
with open('files/amazon_books.csv', 'w', newline='')  as file:
    dict_writer = csv.DictWriter(file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(books)

print("A CSV FILE WAS SAVED")
# Out:
# A CSV FILE WAS SAVED

# %%
df = pd.read_csv('files/amazon_books.csv')
df.head()
# Out:
#                                          description  \
# 0  NCERT Textbooks in English for class 12 - Flam...
# 1                       Grandparents' Bag of Stories
# 2  The Magic of the Lost Temple: Illustrated, eas...
# 3                                Think and Grow Rich
# 4         Very First Sight Words Sentences Level - 2
#
#                                                image  number  \
# 0  https://images-eu.ssl-images-amazon.com/images...      51
# 1  https://images-eu.ssl-images-amazon.com/images...      52
# 2  https://images-eu.ssl-images-amazon.com/images...      53
# 3  https://images-eu.ssl-images-amazon.com/images...      54
# 4  https://images-eu.ssl-images-amazon.com/images...      55
#
#                    seller  price  ratting
# 0                 Unknown   94.0      4.5
# 1                 Unknown  166.0      4.7
# 2                 Unknown  204.0      4.7
# 3           Napoleon Hill  139.0      4.5
# 4  Dreamland Publications  120.0      4.6

# %%
### Generic function that saves data from amazom

# %%
def scrapAmazon(url, category):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
    req = requests.get(url, headers=headers)
    soup = bs(req.content)
    products = soup.findAll('div', {"class": "a-section a-spacing-none aok-relative"})
    items = []
    for product in products:
        # product number
        product_number = int(str(product.div.span.span.string)[1:])
        # product name and image
        image = product.find('img')
        image_url = image["src"]
        product_name = image['alt']
        # product ratting and price
        
        try:
            product_ratting_price = product.find('div', {"class":"a-icon-row"})
            product_price = float(re.findall(r'\d+.\d{2}', str(product.find('span', {'class': 'p13n-sc-price'}).string).replace(',', ''))[0])
        except:
            product_price = 0
            
        try:
            ratting_ratting = product_ratting_price.find('a').i.span.string
            product_ratting = float(re.findall('\d{1}.\d{1}', ratting_ratting)[0])
        except:
            product_ratting = 2.5
        # prodcuct seller

        try:
            product_seller = str(product.find('a', {'class': 'a-size-small a-link-child'}).text)
        except Exception as e:
            product_seller = "Unknown"

        product_seller
        item = {
            "description": product_name,
            "image": image_url,
            "number":product_number,
            "seller":product_seller,
            "price": product_price,
            "ratting": product_ratting,
            "category": str(category).upper()
        }
        items.append(item)
        
    ## WRITE TO A JSON FILE
    file = open(f'files/amazon_{category.lower()}.json', 'w')
    file.write(json.dumps(items))
    file.close()
    ## WRITTING TO A CSV FILE
    keys = items[0].keys()
    with open(f'files/amazon_{category.lower()}.csv', 'w', newline='')  as file:
        dict_writer = csv.DictWriter(file, keys)
        dict_writer.writeheader()
        dict_writer.writerows(items)

    print("FILES SAVED!!", category)

# %% [markdown]
# ### Getting Books

# %%
amazon = "https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_2?ie=UTF8&pg=2"
category = "BOOKS"
scrapAmazon(amazon, category)
# Out:
# FILES SAVED!! BOOKS

# %% [markdown]
# ### Getting Electronics

# %%
amazon = "https://www.amazon.in/gp/bestsellers/electronics/ref=zg_bs_pg_2?ie=UTF8&pg=2"
category = "ELECTRONICS"
scrapAmazon(amazon, category)
# Out:
# FILES SAVED!! ELECTRONICS

# %% [markdown]
# ### Softwares

# %%
amazon = "https://www.amazon.in/gp/bestsellers/software/ref=zg_bs_pg_2?ie=UTF8&pg=2"
category = "SOFTWARES"
scrapAmazon(amazon, category)
# Out:
# FILES SAVED!! SOFTWARES

# %% [markdown]
# ### Baby products

# %%
amazon = "https://www.amazon.in/gp/bestsellers/baby/ref=zg_bs_pg_2?ie=UTF8&pg=2"
category = "BABY_PRODUCTS"
scrapAmazon(amazon, category)
# Out:
# FILES SAVED!! BABY_PRODUCTS

# %%
url = "https://twitter.com/BBCWorld"
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
req = requests.get(url, headers=headers)
soup = bs(req.content)

# %%
soup.find('div', {'class':'css-1dbjc4n r-eqz5dr r-16y2uox r-1wbh5a2'})

# %%
print(soup
         )
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <meta charset="utf-8"/>
# ...
